# %%
# %run 'polynomial_regression.py'
# Out:
# Degree : 1 Training Error 0.647 Test Error 0.650
# Degree : 2 Training Error 0.592 Test Error 0.675
# Degree : 3 Training Error 0.448 Test Error 1.493
# Degree : 4 Training Error 0.002 Test Error 143.157
# Degree : 5 Training Error 0.000 Test Error 673.380

# %% [markdown]
# ## Conclusions
#
# With higher degree, training error reduces but testing error increases. Therefore we can conclude that higher degree polynomials are overfitting the data.
