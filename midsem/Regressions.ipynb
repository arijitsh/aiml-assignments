# %%
# %run 'regressions.py'
# Out:
# Coefficients by OLS
#
#
# Private : -396.21
# Accept : 1.68
# Enroll : -0.55
# Top10perc : 71.90
# Top25perc : -27.76
# F.Undergrad : -0.03
# P.Undergrad : 0.07
# Outstate : -0.10
# Room.Board : 0.13
# Books : -0.12
# Personal : 0.02
# PhD : -4.28
# Terminal : -6.54
# S.F.Ratio : 5.95
# perc.alumni : 0.72
# Expend : 0.06
# Grad.Rate : 8.87
#
#
# RMSE =  1033.04
#
#
# Coefficients by Ridge with lambda = 0
#
#
# Private : -396.21
# Accept : 1.68
# Enroll : -0.55
# Top10perc : 71.90
# Top25perc : -27.76
# F.Undergrad : -0.03
# P.Undergrad : 0.07
# Outstate : -0.10
# Room.Board : 0.13
# Books : -0.12
# Personal : 0.02
# PhD : -4.28
# Terminal : -6.54
# S.F.Ratio : 5.95
# perc.alumni : 0.72
# Expend : 0.06
# Grad.Rate : 8.87
#
#
# RMSE =  1033.04
#
#
# Coefficients by Ridge with lambda = 4
#
#
# Private : -341.31
# Accept : 1.68
# Enroll : -0.55
# Top10perc : 71.86
# Top25perc : -27.77
# F.Undergrad : -0.02
# P.Undergrad : 0.07
# Outstate : -0.11
# Room.Board : 0.13
# Books : -0.12
# ...

# %% [markdown]
# ## Comment on Results by Ridge
#
# Ridge Regression gives almost same error as OLS.
# Least error is for lambda = 2301
# But the error is almost same as OLS.
#
# ## Comment on Results by Lasso
#
# Lasso Regression gives almost same error as OLS/Ridge, a little bit better.
# Least error is for lambda = 326
# But the error is almost same as OLS/Ridge.
# Lasso is using all the parameters, therefore we can conclude there is no significant gain by using Lasso.
